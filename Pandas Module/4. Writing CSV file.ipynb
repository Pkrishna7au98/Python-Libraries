# %% [markdown]
# # Writing the CSV File

# %%
import pandas as pd

# %%
df = pd.read_csv('c:\\Users\\KRISHNA\\Desktop\\Programming\\Data Science\\Test CSV files\\rows10.csv')
df
# Out:
#    S.NO                                               Name  \
# 0     1   Eldon Base for stackable storage shelf, platinum
# 1     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 3     4                                               R380
# 4     5                           Holmes HEPA Air Purifier
# 5     6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs
# 6     7  Angle-D Binders with Locking Rings, Label Holders
# 7     8            SAFCO Mobile Desk Side File, Wire Frame
# 8     9              SAFCO Commercial Wire Shelving, Black
# 9    10                                          Xerox 198
#
#                   Frc  val    deval     anl  grscc location  \
# 0  Muhammed MacIntyre    3  -213.25   38.94  35.00  Nunavut
# 1        Barry French  293   457.81  208.16  68.02  Nunavut
# 2        Barry French  293    46.71    8.69   2.99  Nunavut
# 3       Clay Rozendal  483  1198.97  195.99   3.99  Nunavut
# ...

# %% [markdown]
# To check the all coloumn Names

# %%
df.columns
# Out:
# Index(['S.NO', 'Name', 'Frc', 'val', 'deval', 'anl', 'grscc', 'location',
#        'part', 'mean'],
#       dtype='object')

# %% [markdown]
# Playing with the rows of DataFrame

# %%
pd.read_csv('c:\\Users\\KRISHNA\\Desktop\\Programming\\Data Science\\Test CSV files\\rows10.csv',nrows=4)
# Out:
#    S.NO                                               Name  \
# 0     1   Eldon Base for stackable storage shelf, platinum
# 1     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 3     4                                               R380
#
#                   Frc  val    deval     anl  grscc location  \
# 0  Muhammed MacIntyre    3  -213.25   38.94  35.00  Nunavut
# 1        Barry French  293   457.81  208.16  68.02  Nunavut
# 2        Barry French  293    46.71    8.69   2.99  Nunavut
# 3       Clay Rozendal  483  1198.97  195.99   3.99  Nunavut
#
#                              part  mean
# 0          Storage & Organization  0.80
# 1                      Appliances  0.58
# 2  Binders and Binder Accessories  0.39
# 3    Telephones and Communication  0.58

# %%
pd.read_csv('c:\\Users\\KRISHNA\\Desktop\\Programming\\Data Science\\Test CSV files\\rows10.csv',skiprows = 3)
# Out:
#     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl     Barry French  \
# 0   4                                               R380    Clay Rozendal
# 1   5                           Holmes HEPA Air Purifier   Carlos Soltero
# 2   6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs   Carlos Soltero
# 3   7  Angle-D Binders with Locking Rings, Label Holders     Carl Jackson
# 4   8            SAFCO Mobile Desk Side File, Wire Frame     Carl Jackson
# 5   9              SAFCO Commercial Wire Shelving, Black   Monica Federle
# 6  10                                          Xerox 198  Dorothy Badders
#
#    293    46.71    8.69   2.99  Nunavut  Binders and Binder Accessories  0.39
# 0  483  1198.97  195.99   3.99  Nunavut    Telephones and Communication  0.58
# 1  515    30.94   21.78   5.94  Nunavut                      Appliances  0.50
# 2  515     4.43    6.64   4.95  Nunavut              Office Furnishings  0.37
# ...

# %%
pd.read_csv('c:\\Users\\KRISHNA\\Desktop\\Programming\\Data Science\\Test CSV files\\rows10.csv',skiprows = [1,3,5,7,9])
# Out:
#    S.NO                                               Name              Frc  \
# 0     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...     Barry French
# 1     4                                               R380    Clay Rozendal
# 2     6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs   Carlos Soltero
# 3     8            SAFCO Mobile Desk Side File, Wire Frame     Carl Jackson
# 4    10                                          Xerox 198  Dorothy Badders
#
#    val    deval     anl  grscc location                          part  mean
# 0  293   457.81  208.16  68.02  Nunavut                    Appliances  0.58
# 1  483  1198.97  195.99   3.99  Nunavut  Telephones and Communication  0.58
# 2  515     4.43    6.64   4.95  Nunavut            Office Furnishings  0.37
# 3  613   127.70   42.76   6.22  Nunavut        Storage & Organization   NaN
# 4  678  -226.36    4.98   8.33  Nunavut                         Paper  0.38

# %% [markdown]
# Playing with Columns

# %%
pd.read_csv('c:\\Users\\KRISHNA\\Desktop\\Programming\\Data Science\\Test CSV files\\rows10.csv',usecols = [3])
# Out:
#    val
# 0    3
# 1  293
# 2  293
# 3  483
# 4  515
# 5  515
# 6  613
# 7  613
# 8  643
# 9  678

# %%
pd.read_csv('c:\\Users\\KRISHNA\\Desktop\\Programming\\Data Science\\Test CSV files\\rows10.csv',usecols = [2,3,4])
# Out:
#                   Frc  val    deval
# 0  Muhammed MacIntyre    3  -213.25
# 1        Barry French  293   457.81
# 2        Barry French  293    46.71
# 3       Clay Rozendal  483  1198.97
# 4      Carlos Soltero  515    30.94
# 5      Carlos Soltero  515     4.43
# 6        Carl Jackson  613   -54.04
# 7        Carl Jackson  613   127.70
# 8      Monica Federle  643  -695.26
# 9     Dorothy Badders  678  -226.36

# %%
pd.read_csv('c:\\Users\\KRISHNA\\Desktop\\Programming\\Data Science\\Test CSV files\\rows10.csv',usecols = [0,1,2,3,4])
# Out:
#    S.NO                                               Name  \
# 0     1   Eldon Base for stackable storage shelf, platinum
# 1     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 3     4                                               R380
# 4     5                           Holmes HEPA Air Purifier
# 5     6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs
# 6     7  Angle-D Binders with Locking Rings, Label Holders
# 7     8            SAFCO Mobile Desk Side File, Wire Frame
# 8     9              SAFCO Commercial Wire Shelving, Black
# 9    10                                          Xerox 198
#
#                   Frc  val    deval
# 0  Muhammed MacIntyre    3  -213.25
# 1        Barry French  293   457.81
# 2        Barry French  293    46.71
# 3       Clay Rozendal  483  1198.97
# 4      Carlos Soltero  515    30.94
# 5      Carlos Soltero  515     4.43
# 6        Carl Jackson  613   -54.04
# ...

# %% [markdown]
# Replacing the INDEX with any particular COLUMN

# %%
pd.read_csv('c:\\Users\\KRISHNA\\Desktop\\Programming\\Data Science\\Test CSV files\\rows10.csv',index_col = [4])
# Out:
#           S.NO                                               Name  \
# deval
# -213.25      1   Eldon Base for stackable storage shelf, platinum
#  457.81      2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
#  46.71       3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
#  1198.97     4                                               R380
#  30.94       5                           Holmes HEPA Air Purifier
#  4.43        6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs
# -54.04       7  Angle-D Binders with Locking Rings, Label Holders
#  127.70      8            SAFCO Mobile Desk Side File, Wire Frame
# -695.26      9              SAFCO Commercial Wire Shelving, Black
# -226.36     10                                          Xerox 198
#
#                          Frc  val     anl  grscc location  \
# deval
# -213.25   Muhammed MacIntyre    3   38.94  35.00  Nunavut
#  457.81         Barry French  293  208.16  68.02  Nunavut
# ...

# %%
pd.read_csv('c:\\Users\\KRISHNA\\Desktop\\Programming\\Data Science\\Test CSV files\\rows10.csv',index_col = 4)
# Out:
#           S.NO                                               Name  \
# deval
# -213.25      1   Eldon Base for stackable storage shelf, platinum
#  457.81      2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
#  46.71       3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
#  1198.97     4                                               R380
#  30.94       5                           Holmes HEPA Air Purifier
#  4.43        6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs
# -54.04       7  Angle-D Binders with Locking Rings, Label Holders
#  127.70      8            SAFCO Mobile Desk Side File, Wire Frame
# -695.26      9              SAFCO Commercial Wire Shelving, Black
# -226.36     10                                          Xerox 198
#
#                          Frc  val     anl  grscc location  \
# deval
# -213.25   Muhammed MacIntyre    3   38.94  35.00  Nunavut
#  457.81         Barry French  293  208.16  68.02  Nunavut
# ...
