# %% [markdown]
# # Pandas Methods

# %% [markdown]
# ## head(), tail()

# %%
import pandas as pd

# %%
df = pd.read_csv('c:\\Users\\KRISHNA\\Desktop\\Programming\\Data Science\\Test CSV files\\rows10.csv')    #head method
df.head()
# Out:
#    S.NO                                               Name  \
# 0     1   Eldon Base for stackable storage shelf, platinum
# 1     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 3     4                                               R380
# 4     5                           Holmes HEPA Air Purifier
#
#                   Frc  val    deval     anl  grscc location  \
# 0  Muhammed MacIntyre    3  -213.25   38.94  35.00  Nunavut
# 1        Barry French  293   457.81  208.16  68.02  Nunavut
# 2        Barry French  293    46.71    8.69   2.99  Nunavut
# 3       Clay Rozendal  483  1198.97  195.99   3.99  Nunavut
# 4      Carlos Soltero  515    30.94   21.78   5.94  Nunavut
#
#                              part  mean
# 0          Storage & Organization  0.80
# 1                      Appliances  0.58
# 2  Binders and Binder Accessories  0.39
# 3    Telephones and Communication  0.58
# 4                      Appliances  0.50

# %%
df = pd.read_csv('c:\\Users\\KRISHNA\\Desktop\\Programming\\Data Science\\Test CSV files\\rows10.csv')    #head method
df.head(3)
# Out:
#    S.NO                                               Name  \
# 0     1   Eldon Base for stackable storage shelf, platinum
# 1     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
#
#                   Frc  val   deval     anl  grscc location  \
# 0  Muhammed MacIntyre    3 -213.25   38.94  35.00  Nunavut
# 1        Barry French  293  457.81  208.16  68.02  Nunavut
# 2        Barry French  293   46.71    8.69   2.99  Nunavut
#
#                              part  mean
# 0          Storage & Organization  0.80
# 1                      Appliances  0.58
# 2  Binders and Binder Accessories  0.39

# %%
df = pd.read_csv('c:\\Users\\KRISHNA\\Desktop\\Programming\\Data Science\\Test CSV files\\rows10.csv')    #tail method
df.tail()
# Out:
#    S.NO                                               Name              Frc  \
# 5     6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs   Carlos Soltero
# 6     7  Angle-D Binders with Locking Rings, Label Holders     Carl Jackson
# 7     8            SAFCO Mobile Desk Side File, Wire Frame     Carl Jackson
# 8     9              SAFCO Commercial Wire Shelving, Black   Monica Federle
# 9    10                                          Xerox 198  Dorothy Badders
#
#    val   deval     anl  grscc location                            part  mean
# 5  515    4.43    6.64   4.95  Nunavut              Office Furnishings  0.37
# 6  613  -54.04    7.30   7.72  Nunavut  Binders and Binder Accessories  0.38
# 7  613  127.70   42.76   6.22  Nunavut          Storage & Organization   NaN
# 8  643 -695.26  138.14  35.00  Nunavut          Storage & Organization   NaN
# 9  678 -226.36    4.98   8.33  Nunavut                           Paper  0.38

# %%
df = pd.read_csv('c:\\Users\\KRISHNA\\Desktop\\Programming\\Data Science\\Test CSV files\\rows10.csv')    #tail method
df.tail(2)
# Out:
#    S.NO                                   Name              Frc  val   deval  \
# 8     9  SAFCO Commercial Wire Shelving, Black   Monica Federle  643 -695.26
# 9    10                              Xerox 198  Dorothy Badders  678 -226.36
#
#       anl  grscc location                    part  mean
# 8  138.14  35.00  Nunavut  Storage & Organization   NaN
# 9    4.98   8.33  Nunavut                   Paper  0.38

# %% [markdown]
# # dtype , true_values , false_values

# %%
df = pd.read_csv('c:\\Users\\KRISHNA\\Desktop\\Programming\\Data Science\\Test CSV files\\rows10.csv',dtype = {'val':'float64'})
df
# Out:
#    S.NO                                               Name  \
# 0     1   Eldon Base for stackable storage shelf, platinum
# 1     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 3     4                                               R380
# 4     5                           Holmes HEPA Air Purifier
# 5     6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs
# 6     7  Angle-D Binders with Locking Rings, Label Holders
# 7     8            SAFCO Mobile Desk Side File, Wire Frame
# 8     9              SAFCO Commercial Wire Shelving, Black
# 9    10                                          Xerox 198
#
#                   Frc    val    deval     anl  grscc location  \
# 0  Muhammed MacIntyre    3.0  -213.25   38.94  35.00  Nunavut
# 1        Barry French  293.0   457.81  208.16  68.02  Nunavut
# 2        Barry French  293.0    46.71    8.69   2.99  Nunavut
# 3       Clay Rozendal  483.0  1198.97  195.99   3.99  Nunavut
# ...

# %%
df = pd.read_csv('c:\\Users\\KRISHNA\\Desktop\\Programming\\Data Science\\Test CSV files\\rows10.csv',dtype = {'val':'str','S.NO':'float64','anl':'int32'})
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# TypeError: Cannot cast array data from dtype('float64') to dtype('int32') according to the rule 'safe'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-25c40c02fcad> in <module>
# ----> 1 df = pd.read_csv('c:\\Users\\KRISHNA\\Desktop\\Programming\\Data Science\\Test CSV files\\rows10.csv',dtype = {'val':'str','S.NO':'float64','anl':'int32'})
#       2 df
#
# ...

# %%
df = pd.read_csv('c:\\Users\\KRISHNA\\Desktop\\Programming\\Data Science\\Test CSV files\\rows10.csv',true_values = ['yes'],false_values = ['no'])
df
# Out:
#    S.NO                                               Name  \
# 0     1   Eldon Base for stackable storage shelf, platinum
# 1     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 3     4                                               R380
# 4     5                           Holmes HEPA Air Purifier
# 5     6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs
# 6     7  Angle-D Binders with Locking Rings, Label Holders
# 7     8            SAFCO Mobile Desk Side File, Wire Frame
# 8     9              SAFCO Commercial Wire Shelving, Black
# 9    10                                          Xerox 198
#
#                   Frc  invert  val    deval     anl  grscc location  \
# 0  Muhammed MacIntyre    True    3  -213.25   38.94  35.00  Nunavut
# 1        Barry French    True  293   457.81  208.16  68.02  Nunavut
# 2        Barry French    True  293    46.71    8.69   2.99  Nunavut
# ...
