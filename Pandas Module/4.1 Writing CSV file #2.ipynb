# %% [markdown]
# # Part 2- Writing CSV files - header,prefix and names

# %%
import pandas as pd

# %%
df = pd.read_csv('c:\\Users\\KRISHNA\\Desktop\\Programming\\Data Science\\Test CSV files\\rows10.csv')
df
# Out:
#    S.NO                                               Name  \
# 0     1   Eldon Base for stackable storage shelf, platinum
# 1     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 3     4                                               R380
# 4     5                           Holmes HEPA Air Purifier
# 5     6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs
# 6     7  Angle-D Binders with Locking Rings, Label Holders
# 7     8            SAFCO Mobile Desk Side File, Wire Frame
# 8     9              SAFCO Commercial Wire Shelving, Black
# 9    10                                          Xerox 198
#
#                   Frc  val    deval     anl  grscc location  \
# 0  Muhammed MacIntyre    3  -213.25   38.94  35.00  Nunavut
# 1        Barry French  293   457.81  208.16  68.02  Nunavut
# 2        Barry French  293    46.71    8.69   2.99  Nunavut
# 3       Clay Rozendal  483  1198.97  195.99   3.99  Nunavut
# ...

# %%
df = pd.read_csv('c:\\Users\\KRISHNA\\Desktop\\Programming\\Data Science\\Test CSV files\\rows10.csv',header = 1)
df
# Out:
#     1   Eldon Base for stackable storage shelf, platinum Muhammed MacIntyre  \
# 0   2  1.7 Cubic Foot Compact "Cube" Office Refrigera...       Barry French
# 1   3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl       Barry French
# 2   4                                               R380      Clay Rozendal
# 3   5                           Holmes HEPA Air Purifier     Carlos Soltero
# 4   6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs     Carlos Soltero
# 5   7  Angle-D Binders with Locking Rings, Label Holders       Carl Jackson
# 6   8            SAFCO Mobile Desk Side File, Wire Frame       Carl Jackson
# 7   9              SAFCO Commercial Wire Shelving, Black     Monica Federle
# 8  10                                          Xerox 198    Dorothy Badders
#
#      3  -213.25   38.94     35  Nunavut          Storage & Organization   0.8
# 0  293   457.81  208.16  68.02  Nunavut                      Appliances  0.58
# ...

# %%
df = pd.read_csv('c:\\Users\\KRISHNA\\Desktop\\Programming\\Data Science\\Test CSV files\\rows10.csv',header = [1])
df
# Out:
#     1   Eldon Base for stackable storage shelf, platinum Muhammed MacIntyre  \
# 0   2  1.7 Cubic Foot Compact "Cube" Office Refrigera...       Barry French
# 1   3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl       Barry French
# 2   4                                               R380      Clay Rozendal
# 3   5                           Holmes HEPA Air Purifier     Carlos Soltero
# 4   6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs     Carlos Soltero
# 5   7  Angle-D Binders with Locking Rings, Label Holders       Carl Jackson
# 6   8            SAFCO Mobile Desk Side File, Wire Frame       Carl Jackson
# 7   9              SAFCO Commercial Wire Shelving, Black     Monica Federle
# 8  10                                          Xerox 198    Dorothy Badders
#
#      3  -213.25   38.94     35  Nunavut          Storage & Organization   0.8
# 0  293   457.81  208.16  68.02  Nunavut                      Appliances  0.58
# ...

# %%
df = pd.read_csv('c:\\Users\\KRISHNA\\Desktop\\Programming\\Data Science\\Test CSV files\\rows10.csv',header = [6])
df
# Out:
#     6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs   Carlos Soltero  \
# 0   7  Angle-D Binders with Locking Rings, Label Holders     Carl Jackson
# 1   8            SAFCO Mobile Desk Side File, Wire Frame     Carl Jackson
# 2   9              SAFCO Commercial Wire Shelving, Black   Monica Federle
# 3  10                                          Xerox 198  Dorothy Badders
#
#    515    4.43    6.64   4.95  Nunavut              Office Furnishings  0.37
# 0  613  -54.04    7.30   7.72  Nunavut  Binders and Binder Accessories  0.38
# 1  613  127.70   42.76   6.22  Nunavut          Storage & Organization   NaN
# 2  643 -695.26  138.14  35.00  Nunavut          Storage & Organization   NaN
# 3  678 -226.36    4.98   8.33  Nunavut                           Paper  0.38

# %%
df = pd.read_csv('c:\\Users\\KRISHNA\\Desktop\\Programming\\Data Science\\Test CSV files\\rows10.csv',header = None)
df
# Out:
#        0                                                  1  \
# 0   S.NO                                               Name
# 1      1   Eldon Base for stackable storage shelf, platinum
# 2      2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 3      3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 4      4                                               R380
# 5      5                           Holmes HEPA Air Purifier
# 6      6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs
# 7      7  Angle-D Binders with Locking Rings, Label Holders
# 8      8            SAFCO Mobile Desk Side File, Wire Frame
# 9      9              SAFCO Commercial Wire Shelving, Black
# 10    10                                          Xerox 198
#
#                      2    3        4       5      6         7  \
# 0                  Frc  val    deval     anl  grscc  location
# 1   Muhammed MacIntyre    3  -213.25   38.94     35   Nunavut
# ...

# %% [markdown]
# PREFIX in Pandas : read_csv

# %%
df = pd.read_csv('c:\\Users\\KRISHNA\\Desktop\\Programming\\Data Science\\Test CSV files\\rows10.csv',header = None, prefix='cols')
df
# Out:
#    cols0                                              cols1  \
# 0   S.NO                                               Name
# 1      1   Eldon Base for stackable storage shelf, platinum
# 2      2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 3      3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 4      4                                               R380
# 5      5                           Holmes HEPA Air Purifier
# 6      6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs
# 7      7  Angle-D Binders with Locking Rings, Label Holders
# 8      8            SAFCO Mobile Desk Side File, Wire Frame
# 9      9              SAFCO Commercial Wire Shelving, Black
# 10    10                                          Xerox 198
#
#                  cols2 cols3    cols4   cols5  cols6     cols7  \
# 0                  Frc   val    deval     anl  grscc  location
# 1   Muhammed MacIntyre     3  -213.25   38.94     35   Nunavut
# ...

# %% [markdown]
# NAMES in Pands : read_csv

# %%
df = pd.read_csv('c:\\Users\\KRISHNA\\Desktop\\Programming\\Data Science\\Test CSV files\\rows10.csv',
                 names=['cols','nm','sd','sdwe','sde','erer','sdww','wqewqs','sdsdwe','swwewde'])
df
# Out:
#     cols                                                 nm  \
# 0   S.NO                                               Name
# 1      1   Eldon Base for stackable storage shelf, platinum
# 2      2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 3      3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 4      4                                               R380
# 5      5                           Holmes HEPA Air Purifier
# 6      6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs
# 7      7  Angle-D Binders with Locking Rings, Label Holders
# 8      8            SAFCO Mobile Desk Side File, Wire Frame
# 9      9              SAFCO Commercial Wire Shelving, Black
# 10    10                                          Xerox 198
#
#                     sd sdwe      sde    erer   sdww    wqewqs  \
# 0                  Frc  val    deval     anl  grscc  location
# 1   Muhammed MacIntyre    3  -213.25   38.94     35   Nunavut
# ...

# %%
df = pd.read_csv('c:\\Users\\KRISHNA\\Desktop\\Programming\\Data Science\\Test CSV files\\rows10.csv',
                 names=['cols','nm','sd','sdwe','sdsdwe','swwewde'])
df
# Out:
#                                                                                    cols  \
# S.NO Name                                               Frc                val    deval
# 1    Eldon Base for stackable storage shelf, platinum   Muhammed MacIntyre 3    -213.25
# 2    1.7 Cubic Foot Compact "Cube" Office Refrigerators Barry French       293   457.81
# 3    Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl   Barry French       293    46.71
# 4    R380                                               Clay Rozendal      483  1198.97
# 5    Holmes HEPA Air Purifier                           Carlos Soltero     515    30.94
# 6    G.E. Longer-Life Indoor Recessed Floodlight Bulbs  Carlos Soltero     515     4.43
# 7    Angle-D Binders with Locking Rings, Label Holders  Carl Jackson       613   -54.04
# 8    SAFCO Mobile Desk Side File, Wire Frame            Carl Jackson       613    127.7
# 9    SAFCO Commercial Wire Shelving, Black              Monica Federle     643  -695.26
# ...
