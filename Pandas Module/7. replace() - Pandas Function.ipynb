# %% [markdown]
# # replace() Function

# %%
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\KRISHNA\\Desktop\\Programming\\Data Science\\Test CSV files\\rows10.csv')
df
# Out:
#    S.NO                                               Name  \
# 0     1   Eldon Base for stackable storage shelf, platinum
# 1     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 3     4                                               R380
# 4     5                                                 no
# 5     6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs
# 6     7  Angle-D Binders with Locking Rings, Label Holders
# 7     8            SAFCO Mobile Desk Side File, Wire Frame
# 8     9              SAFCO Commercial Wire Shelving, Black
# 9    10                                          Xerox 198
#
#                   Frc invert  val    deval     anl  grscc location  \
# 0  Muhammed MacIntyre    yes    3  -213.25   38.94  35.00  Nunavut
# 1        Barry French    yes  293   457.81  208.16  68.02       no
# 2        Barry French    yes  293      yes    8.69   2.99  Nunavut
# ...

# %%
df.replace()       #By default it takes forwardfill or ffill or pad
# Out:
#    S.NO                                               Name  \
# 0     1   Eldon Base for stackable storage shelf, platinum
# 1     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 3     4                                               R380
# 4     5                                                 no
# 5     6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs
# 6     7  Angle-D Binders with Locking Rings, Label Holders
# 7     8            SAFCO Mobile Desk Side File, Wire Frame
# 8     9              SAFCO Commercial Wire Shelving, Black
# 9    10                                          Xerox 198
#
#                   Frc invert  val    deval     anl  grscc location  \
# 0  Muhammed MacIntyre    yes    3  -213.25   38.94  35.00  Nunavut
# 1        Barry French    yes  293   457.81  208.16  68.02       no
# 2        Barry French    yes  293      yes    8.69   2.99  Nunavut
# ...

# %%
df.replace(to_replace='yes', value = 'proper')
# Out:
#    S.NO                                               Name  \
# 0     1   Eldon Base for stackable storage shelf, platinum
# 1     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 3     4                                               R380
# 4     5                                                 no
# 5     6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs
# 6     7  Angle-D Binders with Locking Rings, Label Holders
# 7     8            SAFCO Mobile Desk Side File, Wire Frame
# 8     9              SAFCO Commercial Wire Shelving, Black
# 9    10                                          Xerox 198
#
#                   Frc  invert  val    deval     anl  grscc location  \
# 0  Muhammed MacIntyre  proper    3  -213.25   38.94  35.00  Nunavut
# 1        Barry French  proper  293   457.81  208.16  68.02       no
# 2        Barry French  proper  293   proper    8.69   2.99  Nunavut
# ...

# %%
df.replace('yes','improper')
# Out:
#    S.NO                                               Name  \
# 0     1   Eldon Base for stackable storage shelf, platinum
# 1     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 3     4                                               R380
# 4     5                                                 no
# 5     6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs
# 6     7  Angle-D Binders with Locking Rings, Label Holders
# 7     8            SAFCO Mobile Desk Side File, Wire Frame
# 8     9              SAFCO Commercial Wire Shelving, Black
# 9    10                                          Xerox 198
#
#                   Frc    invert  val     deval     anl  grscc location  \
# 0  Muhammed MacIntyre  improper    3   -213.25   38.94  35.00  Nunavut
# 1        Barry French  improper  293    457.81  208.16  68.02       no
# 2        Barry French  improper  293  improper    8.69   2.99  Nunavut
# ...

# %%
df.replace([1,2,3,4,5],0)
# Out:
#    S.NO                                               Name  \
# 0     0   Eldon Base for stackable storage shelf, platinum
# 1     0  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2     0   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 3     0                                               R380
# 4     0                                                 no
# 5     6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs
# 6     7  Angle-D Binders with Locking Rings, Label Holders
# 7     8            SAFCO Mobile Desk Side File, Wire Frame
# 8     9              SAFCO Commercial Wire Shelving, Black
# 9    10                                          Xerox 198
#
#                   Frc invert  val    deval     anl  grscc location  \
# 0  Muhammed MacIntyre    yes    0  -213.25   38.94  35.00  Nunavut
# 1        Barry French    yes  293   457.81  208.16  68.02       no
# 2        Barry French    yes  293      yes    8.69   2.99  Nunavut
# ...

# %%
df.replace([6,7,8],[11,21,31])
# Out:
#    S.NO                                               Name  \
# 0     1   Eldon Base for stackable storage shelf, platinum
# 1     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 3     4                                               R380
# 4     5                                                 no
# 5    11  G.E. Longer-Life Indoor Recessed Floodlight Bulbs
# 6    21  Angle-D Binders with Locking Rings, Label Holders
# 7    31            SAFCO Mobile Desk Side File, Wire Frame
# 8     9              SAFCO Commercial Wire Shelving, Black
# 9    10                                          Xerox 198
#
#                   Frc invert  val    deval     anl  grscc location  \
# 0  Muhammed MacIntyre    yes    3  -213.25   38.94  35.00  Nunavut
# 1        Barry French    yes  293   457.81  208.16  68.02       no
# 2        Barry French    yes  293      yes    8.69   2.99  Nunavut
# ...

# %%
df.replace({'location':'Nunavut'}, 'non indic')
# Out:
#    S.NO                                               Name  \
# 0     1   Eldon Base for stackable storage shelf, platinum
# 1     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 3     4                                               R380
# 4     5                                                 no
# 5     6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs
# 6     7  Angle-D Binders with Locking Rings, Label Holders
# 7     8            SAFCO Mobile Desk Side File, Wire Frame
# 8     9              SAFCO Commercial Wire Shelving, Black
# 9    10                                          Xerox 198
#
#                   Frc invert  val    deval     anl  grscc   location  \
# 0  Muhammed MacIntyre    yes    3  -213.25   38.94  35.00  non indic
# 1        Barry French    yes  293   457.81  208.16  68.02         no
# 2        Barry French    yes  293      yes    8.69   2.99  non indic
# ...

# %%
df.replace({'location':'Nunavut','invert':'no'},'indic')
# Out:
#    S.NO                                               Name  \
# 0     1   Eldon Base for stackable storage shelf, platinum
# 1     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 3     4                                               R380
# 4     5                                                 no
# 5     6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs
# 6     7  Angle-D Binders with Locking Rings, Label Holders
# 7     8            SAFCO Mobile Desk Side File, Wire Frame
# 8     9              SAFCO Commercial Wire Shelving, Black
# 9    10                                          Xerox 198
#
#                   Frc invert  val    deval     anl  grscc location  \
# 0  Muhammed MacIntyre    yes    3  -213.25   38.94  35.00    indic
# 1        Barry French    yes  293   457.81  208.16  68.02       no
# 2        Barry French    yes  293      yes    8.69   2.99    indic
# ...

# %%
df.replace('[A-Za-z]',0 , regex = True)
# Out:
#    S.NO  Name  Frc  invert  val    deval     anl  grscc  location  part  mean
# 0     1     0  0.0       0    3  -213.25   38.94  35.00         0   0.0  0.80
# 1     2     0  0.0       0  293   457.81  208.16  68.02         0   0.0   NaN
# 2     3     0  0.0       0  293        0    8.69   2.99         0   0.0  0.39
# 3     4     0  0.0       0  483  1198.97  195.99   3.99         0   NaN  0.58
# 4     5     0  0.0       0  515    30.94   21.78   5.94         0   0.0  0.50
# 5     6     0  0.0       0  515        0    6.64   4.95         0   0.0  0.37
# 6     7     0  0.0       0  613   -54.04    7.30   7.72         0   0.0  0.38
# 7     8     0  NaN       0  613    127.7   42.76   6.22         0   0.0   NaN
# 8     9     0  0.0       0  643        0  138.14  35.00         0   0.0   NaN
# 9    10     0  0.0       0  678  -226.36    4.98   8.33         0   0.0  0.38

# %%
df.replace({'location':'[A-Za-z]'},56, regex=True)
# Out:
#    S.NO                                               Name  \
# 0     1   Eldon Base for stackable storage shelf, platinum
# 1     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 3     4                                               R380
# 4     5                                                 no
# 5     6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs
# 6     7  Angle-D Binders with Locking Rings, Label Holders
# 7     8            SAFCO Mobile Desk Side File, Wire Frame
# 8     9              SAFCO Commercial Wire Shelving, Black
# 9    10                                          Xerox 198
#
#                   Frc invert  val    deval     anl  grscc  location  \
# 0  Muhammed MacIntyre    yes    3  -213.25   38.94  35.00        56
# 1        Barry French    yes  293   457.81  208.16  68.02        56
# 2        Barry French    yes  293      yes    8.69   2.99        56
# ...

# %%
df.replace(0.38, method='ffill')
# Out:
#    S.NO                                               Name  \
# 0     1   Eldon Base for stackable storage shelf, platinum
# 1     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 3     4                                               R380
# 4     5                                                 no
# 5     6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs
# 6     7  Angle-D Binders with Locking Rings, Label Holders
# 7     8            SAFCO Mobile Desk Side File, Wire Frame
# 8     9              SAFCO Commercial Wire Shelving, Black
# 9    10                                          Xerox 198
#
#                   Frc invert  val    deval     anl  grscc location  \
# 0  Muhammed MacIntyre    yes    3  -213.25   38.94  35.00  Nunavut
# 1        Barry French    yes  293   457.81  208.16  68.02       no
# 2        Barry French    yes  293      yes    8.69   2.99  Nunavut
# ...

# %%
df.replace(0.38, method='bfill')
# Out:
#    S.NO                                               Name  \
# 0     1   Eldon Base for stackable storage shelf, platinum
# 1     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 3     4                                               R380
# 4     5                                                 no
# 5     6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs
# 6     7  Angle-D Binders with Locking Rings, Label Holders
# 7     8            SAFCO Mobile Desk Side File, Wire Frame
# 8     9              SAFCO Commercial Wire Shelving, Black
# 9    10                                          Xerox 198
#
#                   Frc invert  val    deval     anl  grscc location  \
# 0  Muhammed MacIntyre    yes    3  -213.25   38.94  35.00  Nunavut
# 1        Barry French    yes  293   457.81  208.16  68.02       no
# 2        Barry French    yes  293      yes    8.69   2.99  Nunavut
# ...

# %%
df.replace(0.37, method='bfill',limit=3)
# Out:
#    S.NO                                               Name  \
# 0     1   Eldon Base for stackable storage shelf, platinum
# 1     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 3     4                                               R380
# 4     5                                                 no
# 5     6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs
# 6     7  Angle-D Binders with Locking Rings, Label Holders
# 7     8            SAFCO Mobile Desk Side File, Wire Frame
# 8     9              SAFCO Commercial Wire Shelving, Black
# 9    10                                          Xerox 198
#
#                   Frc invert  val    deval     anl  grscc location  \
# 0  Muhammed MacIntyre    yes    3  -213.25   38.94  35.00  Nunavut
# 1        Barry French    yes  293   457.81  208.16  68.02       no
# 2        Barry French    yes  293      yes    8.69   2.99  Nunavut
# ...

# %%
df.replace(0.38,inplace=False)
# Out:
#    S.NO                                               Name  \
# 0     1   Eldon Base for stackable storage shelf, platinum
# 1     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 3     4                                               R380
# 4     5                                                 no
# 5     6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs
# 6     7  Angle-D Binders with Locking Rings, Label Holders
# 7     8            SAFCO Mobile Desk Side File, Wire Frame
# 8     9              SAFCO Commercial Wire Shelving, Black
# 9    10                                          Xerox 198
#
#                   Frc invert  val    deval     anl  grscc location  \
# 0  Muhammed MacIntyre    yes    3  -213.25   38.94  35.00  Nunavut
# 1        Barry French    yes  293   457.81  208.16  68.02       no
# 2        Barry French    yes  293      yes    8.69   2.99  Nunavut
# ...

# %%
df.replace('yes',0.38,inplace=True)
df
# Out:
#    S.NO                                               Name  \
# 0     1   Eldon Base for stackable storage shelf, platinum
# 1     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 3     4                                               R380
# 4     5                                                 no
# 5     6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs
# 6     7  Angle-D Binders with Locking Rings, Label Holders
# 7     8            SAFCO Mobile Desk Side File, Wire Frame
# 8     9              SAFCO Commercial Wire Shelving, Black
# 9    10                                          Xerox 198
#
#                   Frc invert  val    deval     anl  grscc location  \
# 0  Muhammed MacIntyre   0.38    3  -213.25   38.94  35.00  Nunavut
# 1        Barry French   0.38  293   457.81  208.16  68.02       no
# 2        Barry French   0.38  293     0.38    8.69   2.99  Nunavut
# ...
