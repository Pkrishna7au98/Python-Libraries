# %% [markdown]
# # fillna() - method

# %%
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\KRISHNA\\Desktop\\Programming\\Data Science\\Test CSV files\\rows10.csv')
df
# Out:
#    S.NO                                               Name  \
# 0     1   Eldon Base for stackable storage shelf, platinum
# 1     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 3     4                                               R380
# 4     5                                                 no
# 5     6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs
# 6     7  Angle-D Binders with Locking Rings, Label Holders
# 7     8            SAFCO Mobile Desk Side File, Wire Frame
# 8     9              SAFCO Commercial Wire Shelving, Black
# 9    10                                          Xerox 198
#
#                   Frc invert  val    deval     anl  grscc location  \
# 0  Muhammed MacIntyre    yes    3  -213.25   38.94  35.00  Nunavut
# 1        Barry French    yes  293   457.81  208.16  68.02       no
# 2        Barry French    yes  293      yes    8.69   2.99  Nunavut
# ...

# %%
df = pd.read_csv('C:\\Users\\KRISHNA\\Desktop\\Programming\\Data Science\\Test CSV files\\rows10.csv')
df.fillna(77)
# Out:
#    S.NO                                               Name  \
# 0     1   Eldon Base for stackable storage shelf, platinum
# 1     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 3     4                                               R380
# 4     5                                                 no
# 5     6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs
# 6     7  Angle-D Binders with Locking Rings, Label Holders
# 7     8            SAFCO Mobile Desk Side File, Wire Frame
# 8     9              SAFCO Commercial Wire Shelving, Black
# 9    10                                          Xerox 198
#
#                   Frc invert  val    deval     anl  grscc location  \
# 0  Muhammed MacIntyre    yes    3  -213.25   38.94  35.00  Nunavut
# 1        Barry French    yes  293   457.81  208.16  68.02       no
# 2        Barry French    yes  293      yes    8.69   2.99  Nunavut
# ...

# %%
df = pd.read_csv('C:\\Users\\KRISHNA\\Desktop\\Programming\\Data Science\\Test CSV files\\rows10.csv')
df.fillna({'mean':123321,'Frc':'No FRC'})
# Out:
#    S.NO                                               Name  \
# 0     1   Eldon Base for stackable storage shelf, platinum
# 1     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 3     4                                               R380
# 4     5                                                 no
# 5     6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs
# 6     7  Angle-D Binders with Locking Rings, Label Holders
# 7     8            SAFCO Mobile Desk Side File, Wire Frame
# 8     9              SAFCO Commercial Wire Shelving, Black
# 9    10                                          Xerox 198
#
#                   Frc invert  val    deval     anl  grscc location  \
# 0  Muhammed MacIntyre    yes    3  -213.25   38.94  35.00  Nunavut
# 1        Barry French    yes  293   457.81  208.16  68.02       no
# 2        Barry French    yes  293      yes    8.69   2.99  Nunavut
# ...

# %%
df = pd.read_csv('C:\\Users\\KRISHNA\\Desktop\\Programming\\Data Science\\Test CSV files\\rows10.csv')
df.isnull().sum().sum()
# Out:
# 5

# %%
df = pd.read_csv('C:\\Users\\KRISHNA\\Desktop\\Programming\\Data Science\\Test CSV files\\rows10.csv')
df.fillna({'mean':pd.Series([11,22,33],index=[1,7,8])})
# Out:
#    S.NO                                               Name  \
# 0     1   Eldon Base for stackable storage shelf, platinum
# 1     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 3     4                                               R380
# 4     5                                                 no
# 5     6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs
# 6     7  Angle-D Binders with Locking Rings, Label Holders
# 7     8            SAFCO Mobile Desk Side File, Wire Frame
# 8     9              SAFCO Commercial Wire Shelving, Black
# 9    10                                          Xerox 198
#
#                   Frc invert  val    deval     anl  grscc location  \
# 0  Muhammed MacIntyre    yes    3  -213.25   38.94  35.00  Nunavut
# 1        Barry French    yes  293   457.81  208.16  68.02       no
# 2        Barry French    yes  293      yes    8.69   2.99  Nunavut
# ...

# %%
df = pd.read_csv('C:\\Users\\KRISHNA\\Desktop\\Programming\\Data Science\\Test CSV files\\rows10.csv')
df.fillna(method = 'ffill')
# Out:
#    S.NO                                               Name  \
# 0     1   Eldon Base for stackable storage shelf, platinum
# 1     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 3     4                                               R380
# 4     5                                                 no
# 5     6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs
# 6     7  Angle-D Binders with Locking Rings, Label Holders
# 7     8            SAFCO Mobile Desk Side File, Wire Frame
# 8     9              SAFCO Commercial Wire Shelving, Black
# 9    10                                          Xerox 198
#
#                   Frc invert  val    deval     anl  grscc location  \
# 0  Muhammed MacIntyre    yes    3  -213.25   38.94  35.00  Nunavut
# 1        Barry French    yes  293   457.81  208.16  68.02       no
# 2        Barry French    yes  293      yes    8.69   2.99  Nunavut
# ...

# %%
df = pd.read_csv('C:\\Users\\KRISHNA\\Desktop\\Programming\\Data Science\\Test CSV files\\rows10.csv')
df.fillna(axis = 1, method = 'ffill')
# Out:
#   S.NO                                               Name  \
# 0    1   Eldon Base for stackable storage shelf, platinum
# 1    2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2    3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 3    4                                               R380
# 4    5                                                 no
# 5    6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs
# 6    7  Angle-D Binders with Locking Rings, Label Holders
# 7    8            SAFCO Mobile Desk Side File, Wire Frame
# 8    9              SAFCO Commercial Wire Shelving, Black
# 9   10                                          Xerox 198
#
#                                        Frc invert  val    deval     anl  \
# 0                       Muhammed MacIntyre    yes    3  -213.25   38.94
# 1                             Barry French    yes  293   457.81  208.16
# 2                             Barry French    yes  293      yes    8.69
# ...

# %%
df = pd.read_csv('C:\\Users\\KRISHNA\\Desktop\\Programming\\Data Science\\Test CSV files\\rows10.csv')
df.fillna(axis = 1, method = 'bfill')
# Out:
#   S.NO                                               Name                 Frc  \
# 0    1   Eldon Base for stackable storage shelf, platinum  Muhammed MacIntyre
# 1    2  1.7 Cubic Foot Compact "Cube" Office Refrigera...        Barry French
# 2    3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl        Barry French
# 3    4                                               R380       Clay Rozendal
# 4    5                                                 no                 yes
# 5    6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs      Carlos Soltero
# 6    7  Angle-D Binders with Locking Rings, Label Holders        Carl Jackson
# 7    8            SAFCO Mobile Desk Side File, Wire Frame                  no
# 8    9              SAFCO Commercial Wire Shelving, Black      Monica Federle
# 9   10                                          Xerox 198     Dorothy Badders
#
#   invert  val    deval     anl  grscc location  \
# 0    yes    3  -213.25   38.94     35  Nunavut
# ...

# %%
df = pd.read_csv('C:\\Users\\KRISHNA\\Desktop\\Programming\\Data Science\\Test CSV files\\rows10.csv')
df.fillna( method = 'bfill')
# Out:
#    S.NO                                               Name  \
# 0     1   Eldon Base for stackable storage shelf, platinum
# 1     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 3     4                                               R380
# 4     5                                                 no
# 5     6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs
# 6     7  Angle-D Binders with Locking Rings, Label Holders
# 7     8            SAFCO Mobile Desk Side File, Wire Frame
# 8     9              SAFCO Commercial Wire Shelving, Black
# 9    10                                          Xerox 198
#
#                   Frc invert  val    deval     anl  grscc location  \
# 0  Muhammed MacIntyre    yes    3  -213.25   38.94  35.00  Nunavut
# 1        Barry French    yes  293   457.81  208.16  68.02       no
# 2        Barry French    yes  293      yes    8.69   2.99  Nunavut
# ...

# %%
df = pd.read_csv('C:\\Users\\KRISHNA\\Desktop\\Programming\\Data Science\\Test CSV files\\rows10.csv')
df.fillna(99,limit=2)            #limit must be greater than 0(ZERO).
# Out:
#    S.NO                                               Name  \
# 0     1   Eldon Base for stackable storage shelf, platinum
# 1     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 3     4                                               R380
# 4     5                                                 no
# 5     6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs
# 6     7  Angle-D Binders with Locking Rings, Label Holders
# 7     8            SAFCO Mobile Desk Side File, Wire Frame
# 8     9              SAFCO Commercial Wire Shelving, Black
# 9    10                                          Xerox 198
#
#                   Frc invert  val    deval     anl  grscc location  \
# 0  Muhammed MacIntyre    yes    3  -213.25   38.94  35.00  Nunavut
# 1        Barry French    yes  293   457.81  208.16  68.02       no
# 2        Barry French    yes  293      yes    8.69   2.99  Nunavut
# ...

# %%
df = pd.read_csv('C:\\Users\\KRISHNA\\Desktop\\Programming\\Data Science\\Test CSV files\\rows10.csv')
df.fillna(99,inplace=True)
df
# Out:
#    S.NO                                               Name  \
# 0     1   Eldon Base for stackable storage shelf, platinum
# 1     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 3     4                                               R380
# 4     5                                                 no
# 5     6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs
# 6     7  Angle-D Binders with Locking Rings, Label Holders
# 7     8            SAFCO Mobile Desk Side File, Wire Frame
# 8     9              SAFCO Commercial Wire Shelving, Black
# 9    10                                          Xerox 198
#
#                   Frc invert  val    deval     anl  grscc location  \
# 0  Muhammed MacIntyre    yes    3  -213.25   38.94  35.00  Nunavut
# 1        Barry French    yes  293   457.81  208.16  68.02       no
# 2        Barry French    yes  293      yes    8.69   2.99  Nunavut
# ...

# %%
df = pd.read_csv('C:\\Users\\KRISHNA\\Desktop\\Programming\\Data Science\\Test CSV files\\rows10.csv')
df.fillna(99,inplace=False)
df
# Out:
#    S.NO                                               Name  \
# 0     1   Eldon Base for stackable storage shelf, platinum
# 1     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 3     4                                               R380
# 4     5                                                 no
# 5     6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs
# 6     7  Angle-D Binders with Locking Rings, Label Holders
# 7     8            SAFCO Mobile Desk Side File, Wire Frame
# 8     9              SAFCO Commercial Wire Shelving, Black
# 9    10                                          Xerox 198
#
#                   Frc invert  val    deval     anl  grscc location  \
# 0  Muhammed MacIntyre    yes    3  -213.25   38.94  35.00  Nunavut
# 1        Barry French    yes  293   457.81  208.16  68.02       no
# 2        Barry French    yes  293      yes    8.69   2.99  Nunavut
# ...
