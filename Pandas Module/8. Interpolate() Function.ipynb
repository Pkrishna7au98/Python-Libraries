# %% [markdown]
# # Interpolate() Function

# %%
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\KRISHNA\\Desktop\\Programming\\Data Science\\Test CSV files\\rows10.csv')
df
# Out:
#          Date  S.NO                                               Name  \
# 0  01-12-2021     1   Eldon Base for stackable storage shelf, platinum
# 1  02-12-2021     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2  03-12-2021     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 3  04-12-2021     4                                               R380
# 4  05-12-2021     5                                                 no
# 5  06-12-2021     6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs
# 6  07-12-2021     7  Angle-D Binders with Locking Rings, Label Holders
# 7  08-12-2021     8            SAFCO Mobile Desk Side File, Wire Frame
# 8  09-12-2021     9              SAFCO Commercial Wire Shelving, Black
# 9  10-12-2021    10                                          Xerox 198
#
#                   Frc invert    val    deval     anl  grscc location  \
# 0  Muhammed MacIntyre    yes    3.0  -213.25   38.94  35.00  Nunavut
# ...

# %%
df.interpolate()
# Out:
#          Date  S.NO                                               Name  \
# 0  01-12-2021     1   Eldon Base for stackable storage shelf, platinum
# 1         NaN     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2  03-12-2021     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 3  04-12-2021     4                                               R380
# 4  05-12-2021     5                                                 no
# 5         NaN     6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs
# 6  07-12-2021     7  Angle-D Binders with Locking Rings, Label Holders
# 7  08-12-2021     8            SAFCO Mobile Desk Side File, Wire Frame
# 8         NaN     9              SAFCO Commercial Wire Shelving, Black
# 9  10-12-2021    10                                          Xerox 198
#
#                   Frc invert    val    deval     anl   grscc location  \
# 0  Muhammed MacIntyre    yes    3.0  -213.25   38.94  35.000  Nunavut
# ...

# %%
df = pd.read_csv('C:\\Users\\KRISHNA\\Desktop\\Programming\\Data Science\\Test CSV files\\rows10.csv',parse_dates=['Date'],index_col = 'Date')
df
# Out:
#             S.NO                                               Name  \
# Date
# 2021-01-12     1   Eldon Base for stackable storage shelf, platinum
# 2021-02-12     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2021-03-12     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 2021-04-12     4                                               R380
# 2021-05-12     5                                                 no
# 2021-06-12     6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs
# 2021-07-12     7  Angle-D Binders with Locking Rings, Label Holders
# 2021-08-12     8            SAFCO Mobile Desk Side File, Wire Frame
# 2021-09-12     9              SAFCO Commercial Wire Shelving, Black
# 2021-10-12    10                                          Xerox 198
#
#                            Frc invert    val    deval     anl  grscc location  \
# Date
# 2021-01-12  Muhammed MacIntyre    yes    3.0  -213.25   38.94  35.00  Nunavut
# ...

# %% [markdown]
# ## Now the Index has been changed with Dates in DateTime datatype. Now we can use the method='time' function.

# %%
df.interpolate(method='time')       #the values will be filled in the blank numerical cells based on dates column.
# Out:
#             S.NO                                               Name  \
# Date
# 2021-01-12     1   Eldon Base for stackable storage shelf, platinum
# 2021-02-12     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2021-03-12     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 2021-04-12     4                                               R380
# 2021-05-12     5                                                 no
# 2021-06-12     6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs
# 2021-07-12     7  Angle-D Binders with Locking Rings, Label Holders
# 2021-08-12     8            SAFCO Mobile Desk Side File, Wire Frame
# 2021-09-12     9              SAFCO Commercial Wire Shelving, Black
# 2021-10-12    10                                          Xerox 198
#
#                            Frc invert         val        deval     anl  \
# Date
# 2021-01-12  Muhammed MacIntyre    yes    3.000000  -213.250000   38.94
# ...

# %%
df.interpolate(method='polynomial',order=1)
# Out:
#             S.NO                                               Name  \
# Date
# 2021-01-12     1   Eldon Base for stackable storage shelf, platinum
# 2021-02-12     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2021-03-12     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 2021-04-12     4                                               R380
# 2021-05-12     5                                                 no
# 2021-06-12     6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs
# 2021-07-12     7  Angle-D Binders with Locking Rings, Label Holders
# 2021-08-12     8            SAFCO Mobile Desk Side File, Wire Frame
# 2021-09-12     9              SAFCO Commercial Wire Shelving, Black
# 2021-10-12    10                                          Xerox 198
#
#                            Frc invert         val        deval     anl  \
# Date
# 2021-01-12  Muhammed MacIntyre    yes    3.000000  -213.250000   38.94
# ...

# %%
df.interpolate(method='spline',order=3)
# Out:
#             S.NO                                               Name  \
# Date
# 2021-01-12     1   Eldon Base for stackable storage shelf, platinum
# 2021-02-12     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2021-03-12     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 2021-04-12     4                                               R380
# 2021-05-12     5                                                 no
# 2021-06-12     6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs
# 2021-07-12     7  Angle-D Binders with Locking Rings, Label Holders
# 2021-08-12     8            SAFCO Mobile Desk Side File, Wire Frame
# 2021-09-12     9              SAFCO Commercial Wire Shelving, Black
# 2021-10-12    10                                          Xerox 198
#
#                            Frc invert         val        deval     anl  \
# Date
# 2021-01-12  Muhammed MacIntyre    yes    3.000000  -213.250000   38.94
# ...

# %%
df.interpolate(area=5)
# Out:
#             S.NO                                               Name  \
# Date
# 2021-01-12     1   Eldon Base for stackable storage shelf, platinum
# 2021-02-12     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2021-03-12     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 2021-04-12     4                                               R380
# 2021-05-12     5                                                 no
# 2021-06-12     6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs
# 2021-07-12     7  Angle-D Binders with Locking Rings, Label Holders
# 2021-08-12     8            SAFCO Mobile Desk Side File, Wire Frame
# 2021-09-12     9              SAFCO Commercial Wire Shelving, Black
# 2021-10-12    10                                          Xerox 198
#
#                            Frc invert    val    deval     anl   grscc  \
# Date
# 2021-01-12  Muhammed MacIntyre    yes    3.0  -213.25   38.94  35.000
# ...

# %%
df.interpolate(limit=1)
# Out:
#             S.NO                                               Name  \
# Date
# 2021-01-12     1   Eldon Base for stackable storage shelf, platinum
# 2021-02-12     2  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# 2021-03-12     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 2021-04-12     4                                               R380
# 2021-05-12     5                                                 no
# 2021-06-12     6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs
# 2021-07-12     7  Angle-D Binders with Locking Rings, Label Holders
# 2021-08-12     8            SAFCO Mobile Desk Side File, Wire Frame
# 2021-09-12     9              SAFCO Commercial Wire Shelving, Black
# 2021-10-12    10                                          Xerox 198
#
#                            Frc invert    val    deval     anl   grscc  \
# Date
# 2021-01-12  Muhammed MacIntyre    yes    3.0  -213.25   38.94  35.000
# ...
