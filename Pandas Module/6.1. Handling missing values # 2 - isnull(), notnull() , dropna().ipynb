# %% [markdown]
# # Pandas Methods

# %% [markdown]
# ## isnull()

# %%
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\KRISHNA\\Desktop\\Programming\\Data Science\\Test CSV files\\rows10.csv')
df
# Out:
#    S.NO                                               Name  \
# 0     1   Eldon Base for stackable storage shelf, platinum
# 1     2                                                NaN
# 2     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 3     4                                               R380
# 4     5                                                 no
# 5     6                                                NaN
# 6     7  Angle-D Binders with Locking Rings, Label Holders
# 7     8            SAFCO Mobile Desk Side File, Wire Frame
# 8     9              SAFCO Commercial Wire Shelving, Black
# 9    10                                          Xerox 198
#
#                   Frc invert  val    deval     anl  grscc location  \
# 0  Muhammed MacIntyre    yes    3  -213.25   38.94  35.00  Nunavut
# 1        Barry French    yes  293      NaN  208.16  68.02       no
# 2        Barry French    yes  293      yes    8.69   2.99  Nunavut
# 3                 NaN     no  483  1198.97  195.99   3.99  Nunavut
# 4                 yes     no  515    30.94   21.78   5.94  Nunavut
# 5      Carlos Soltero    yes  515      NaN    6.64   4.95  Nunavut
# 6        Carl Jackson     no  613   -54.04    7.30   7.72       no
# 7                 NaN     no  613    127.7   42.76   6.22  Nunavut
# 8      Monica Federle    NaN  643      yes  138.14  35.00  Nunavut
# 9     Dorothy Badders     no  678  -226.36    4.98   8.33  Nunavut
#
#                              part  mean
# 0          Storage & Organization  0.80
# 1                      Appliances   NaN
# 2  Binders and Binder Accessories  0.39
# 3                             NaN  0.58
# 4                      Appliances  0.50
# 5              Office Furnishings  0.37
# 6  Binders and Binder Accessories  0.38
# 7          Storage & Organization   NaN
# 8          Storage & Organization   NaN
# 9                           Paper  0.38

# %%
df = pd.read_csv('C:\\Users\\KRISHNA\\Desktop\\Programming\\Data Science\\Test CSV files\\rows10.csv')
df.isnull()
# Out:
#     S.NO   Name    Frc  invert    val  deval    anl  grscc  location   part  \
# 0  False  False  False   False  False  False  False  False     False  False
# 1  False   True  False   False  False   True  False  False     False  False
# 2  False  False  False   False  False  False  False  False     False  False
# 3  False  False   True   False  False  False  False  False     False   True
# 4  False  False  False   False  False  False  False  False     False  False
# 5  False   True  False   False  False   True  False  False     False  False
# 6  False  False  False   False  False  False  False  False     False  False
# 7  False  False   True   False  False  False  False  False     False  False
# 8  False  False  False    True  False  False  False  False     False  False
# 9  False  False  False   False  False  False  False  False     False  False
#
#     mean
# 0  False
# 1   True
# 2  False
# 3  False
# 4  False
# 5  False
# 6  False
# 7   True
# 8   True
# 9  False

# %%
df = pd.read_csv('C:\\Users\\KRISHNA\\Desktop\\Programming\\Data Science\\Test CSV files\\rows10.csv')
df.isnull().sum()
# Out:
# S.NO        0
# Name        2
# Frc         2
# invert      1
# val         0
# deval       2
# anl         0
# grscc       0
# location    0
# part        1
# mean        3
# dtype: int64

# %%
df = pd.read_csv('C:\\Users\\KRISHNA\\Desktop\\Programming\\Data Science\\Test CSV files\\rows10.csv')
df.isnull().sum().sum()
# Out:
# 11

# %% [markdown]
# ## notnull()

# %%
df = pd.read_csv('C:\\Users\\KRISHNA\\Desktop\\Programming\\Data Science\\Test CSV files\\rows10.csv')
df.notnull()
# Out:
#    S.NO   Name    Frc  invert   val  deval   anl  grscc  location   part  \
# 0  True   True   True    True  True   True  True   True      True   True
# 1  True  False   True    True  True  False  True   True      True   True
# 2  True   True   True    True  True   True  True   True      True   True
# 3  True   True  False    True  True   True  True   True      True  False
# 4  True   True   True    True  True   True  True   True      True   True
# 5  True  False   True    True  True  False  True   True      True   True
# 6  True   True   True    True  True   True  True   True      True   True
# 7  True   True  False    True  True   True  True   True      True   True
# 8  True   True   True   False  True   True  True   True      True   True
# 9  True   True   True    True  True   True  True   True      True   True
#
#     mean
# 0   True
# 1  False
# 2   True
# 3   True
# 4   True
# 5   True
# 6   True
# 7  False
# 8  False
# 9   True

# %%
df = pd.read_csv('C:\\Users\\KRISHNA\\Desktop\\Programming\\Data Science\\Test CSV files\\rows10.csv')
df.notnull().sum()
# Out:
# S.NO        10
# Name         8
# Frc          8
# invert       9
# val         10
# deval        8
# anl         10
# grscc       10
# location    10
# part         9
# mean         7
# dtype: int64

# %%
df = pd.read_csv('C:\\Users\\KRISHNA\\Desktop\\Programming\\Data Science\\Test CSV files\\rows10.csv')
df.notnull().sum().sum()
# Out:
# 99

# %% [markdown]
# ## dropna()

# %%
df = pd.read_csv('C:\\Users\\KRISHNA\\Desktop\\Programming\\Data Science\\Test CSV files\\rows10.csv')
df
# Out:
#    S.NO                                               Name  \
# 0     1   Eldon Base for stackable storage shelf, platinum
# 1     2                                                NaN
# 2     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 3     4                                               R380
# 4     5                                                 no
# 5     6                                                NaN
# 6     7  Angle-D Binders with Locking Rings, Label Holders
# 7     8            SAFCO Mobile Desk Side File, Wire Frame
# 8     9              SAFCO Commercial Wire Shelving, Black
# 9    10                                          Xerox 198
#
#                   Frc invert  val    deval     anl  grscc location  \
# 0  Muhammed MacIntyre    yes    3  -213.25   38.94  35.00  Nunavut
# 1        Barry French    yes  293      NaN  208.16  68.02       no
# 2        Barry French    yes  293      yes    8.69   2.99  Nunavut
# 3                 NaN     no  483  1198.97  195.99   3.99  Nunavut
# 4                 yes     no  515    30.94   21.78   5.94  Nunavut
# 5      Carlos Soltero    yes  515      NaN    6.64   4.95  Nunavut
# 6        Carl Jackson     no  613   -54.04    7.30   7.72       no
# 7                 NaN     no  613    127.7   42.76   6.22  Nunavut
# 8      Monica Federle    NaN  643      yes  138.14  35.00  Nunavut
# 9     Dorothy Badders     no  678  -226.36    4.98   8.33  Nunavut
#
#                              part  mean
# 0          Storage & Organization  0.80
# 1                      Appliances   NaN
# 2  Binders and Binder Accessories  0.39
# 3                             NaN  0.58
# 4                      Appliances  0.50
# 5              Office Furnishings  0.37
# 6  Binders and Binder Accessories  0.38
# 7          Storage & Organization   NaN
# 8          Storage & Organization   NaN
# 9                           Paper  0.38

# %%
df = pd.read_csv('C:\\Users\\KRISHNA\\Desktop\\Programming\\Data Science\\Test CSV files\\rows10.csv')
df.dropna()
# Out:
#    S.NO                                               Name  \
# 0     1   Eldon Base for stackable storage shelf, platinum
# 2     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 4     5                                                 no
# 6     7  Angle-D Binders with Locking Rings, Label Holders
# 9    10                                          Xerox 198
#
#                   Frc invert  val    deval    anl  grscc location  \
# 0  Muhammed MacIntyre    yes    3  -213.25  38.94  35.00  Nunavut
# 2        Barry French    yes  293      yes   8.69   2.99  Nunavut
# 4                 yes     no  515    30.94  21.78   5.94  Nunavut
# 6        Carl Jackson     no  613   -54.04   7.30   7.72       no
# 9     Dorothy Badders     no  678  -226.36   4.98   8.33  Nunavut
#
#                              part  mean
# 0          Storage & Organization  0.80
# 2  Binders and Binder Accessories  0.39
# 4                      Appliances  0.50
# 6  Binders and Binder Accessories  0.38
# 9                           Paper  0.38

# %%
df = pd.read_csv('C:\\Users\\KRISHNA\\Desktop\\Programming\\Data Science\\Test CSV files\\rows10.csv')
df.dropna(axis=0 , how='any')
# Out:
#    S.NO                                               Name  \
# 0     1   Eldon Base for stackable storage shelf, platinum
# 2     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 4     5                                                 no
# 6     7  Angle-D Binders with Locking Rings, Label Holders
# 9    10                                          Xerox 198
#
#                   Frc invert  val    deval    anl  grscc location  \
# 0  Muhammed MacIntyre    yes    3  -213.25  38.94  35.00  Nunavut
# 2        Barry French    yes  293      yes   8.69   2.99  Nunavut
# 4                 yes     no  515    30.94  21.78   5.94  Nunavut
# 6        Carl Jackson     no  613   -54.04   7.30   7.72       no
# 9     Dorothy Badders     no  678  -226.36   4.98   8.33  Nunavut
#
#                              part  mean
# 0          Storage & Organization  0.80
# 2  Binders and Binder Accessories  0.39
# 4                      Appliances  0.50
# 6  Binders and Binder Accessories  0.38
# 9                           Paper  0.38

# %%
df = pd.read_csv('C:\\Users\\KRISHNA\\Desktop\\Programming\\Data Science\\Test CSV files\\rows10.csv')
df.dropna(axis=1 , how='any')
# Out:
#    S.NO  val     anl  grscc location
# 0     1    3   38.94  35.00  Nunavut
# 1     2  293  208.16  68.02       no
# 2     3  293    8.69   2.99  Nunavut
# 3     4  483  195.99   3.99  Nunavut
# 4     5  515   21.78   5.94  Nunavut
# 5     6  515    6.64   4.95  Nunavut
# 6     7  613    7.30   7.72       no
# 7     8  613   42.76   6.22  Nunavut
# 8     9  643  138.14  35.00  Nunavut
# 9    10  678    4.98   8.33  Nunavut

# %%
df = pd.read_csv('C:\\Users\\KRISHNA\\Desktop\\Programming\\Data Science\\Test CSV files\\rows10.csv')
df.dropna(axis=0 , how='all')
# Out:
#    S.NO                                              Name                 Frc  \
# 0   1.0  Eldon Base for stackable storage shelf, platinum  Muhammed MacIntyre
# 1   2.0                                               NaN        Barry French
# 2   3.0  Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl        Barry French
# 3   4.0                                              R380                 NaN
# 4   5.0                                                no                 yes
# 5   6.0                                               NaN      Carlos Soltero
# 7   8.0           SAFCO Mobile Desk Side File, Wire Frame                 NaN
# 8   9.0             SAFCO Commercial Wire Shelving, Black      Monica Federle
# 9  10.0                                         Xerox 198     Dorothy Badders
#
#    invert    val    deval     anl  grscc location  \
# 0     NaN    3.0  -213.25   38.94  35.00  Nunavut
# 1     NaN  293.0      NaN  208.16  68.02       no
# 2     NaN  293.0      yes    8.69   2.99  Nunavut
# 3     NaN  483.0  1198.97  195.99   3.99  Nunavut
# 4     NaN  515.0    30.94   21.78   5.94  Nunavut
# 5     NaN  515.0      NaN    6.64   4.95  Nunavut
# 7     NaN  613.0    127.7   42.76   6.22  Nunavut
# 8     NaN  643.0      yes  138.14  35.00  Nunavut
# 9     NaN  678.0  -226.36    4.98   8.33  Nunavut
#
#                              part  mean
# 0          Storage & Organization  0.80
# 1                      Appliances   NaN
# 2  Binders and Binder Accessories  0.39
# 3                             NaN  0.58
# 4                      Appliances  0.50
# 5              Office Furnishings  0.37
# 7          Storage & Organization   NaN
# 8          Storage & Organization   NaN
# 9                           Paper  0.38

# %%
df = pd.read_csv('C:\\Users\\KRISHNA\\Desktop\\Programming\\Data Science\\Test CSV files\\rows10.csv')
df.dropna(axis=1 , how='all')
# Out:
#    S.NO                                              Name                 Frc  \
# 0   1.0  Eldon Base for stackable storage shelf, platinum  Muhammed MacIntyre
# 1   2.0                                               NaN        Barry French
# 2   3.0  Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl        Barry French
# 3   4.0                                              R380                 NaN
# 4   5.0                                                no                 yes
# 5   6.0                                               NaN      Carlos Soltero
# 6   NaN                                               NaN                 NaN
# 7   8.0           SAFCO Mobile Desk Side File, Wire Frame                 NaN
# 8   9.0             SAFCO Commercial Wire Shelving, Black      Monica Federle
# 9  10.0                                         Xerox 198     Dorothy Badders
#
#      val    deval     anl  grscc location                            part  \
# 0    3.0  -213.25   38.94  35.00  Nunavut          Storage & Organization
# 1  293.0      NaN  208.16  68.02       no                      Appliances
# 2  293.0      yes    8.69   2.99  Nunavut  Binders and Binder Accessories
# 3  483.0  1198.97  195.99   3.99  Nunavut                             NaN
# 4  515.0    30.94   21.78   5.94  Nunavut                      Appliances
# 5  515.0      NaN    6.64   4.95  Nunavut              Office Furnishings
# 6    NaN      NaN     NaN    NaN      NaN                             NaN
# 7  613.0    127.7   42.76   6.22  Nunavut          Storage & Organization
# 8  643.0      yes  138.14  35.00  Nunavut          Storage & Organization
# 9  678.0  -226.36    4.98   8.33  Nunavut                           Paper
#
#    mean
# 0  0.80
# 1   NaN
# 2  0.39
# 3  0.58
# 4  0.50
# 5  0.37
# 6   NaN
# 7   NaN
# 8   NaN
# 9  0.38

# %%
df = pd.read_csv('C:\\Users\\KRISHNA\\Desktop\\Programming\\Data Science\\Test CSV files\\rows10.csv')
df.dropna(thresh = 8)
# Out:
#    S.NO                                              Name                 Frc  \
# 0   1.0  Eldon Base for stackable storage shelf, platinum  Muhammed MacIntyre
# 2   3.0  Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl        Barry French
# 3   4.0                                              R380                 NaN
# 4   5.0                                                no                 yes
# 5   6.0                                               NaN      Carlos Soltero
# 7   8.0           SAFCO Mobile Desk Side File, Wire Frame                 NaN
# 8   9.0             SAFCO Commercial Wire Shelving, Black      Monica Federle
# 9  10.0                                         Xerox 198     Dorothy Badders
#
#    invert    val    deval     anl  grscc location  \
# 0     NaN    3.0  -213.25   38.94  35.00  Nunavut
# 2     NaN  293.0      yes    8.69   2.99  Nunavut
# 3     NaN  483.0  1198.97  195.99   3.99  Nunavut
# 4     NaN  515.0    30.94   21.78   5.94  Nunavut
# 5     NaN  515.0      NaN    6.64   4.95  Nunavut
# 7     NaN  613.0    127.7   42.76   6.22  Nunavut
# 8     NaN  643.0      yes  138.14  35.00  Nunavut
# 9     NaN  678.0  -226.36    4.98   8.33  Nunavut
#
#                              part  mean
# 0          Storage & Organization  0.80
# 2  Binders and Binder Accessories  0.39
# 3                             NaN  0.58
# 4                      Appliances  0.50
# 5              Office Furnishings  0.37
# 7          Storage & Organization   NaN
# 8          Storage & Organization   NaN
# 9                           Paper  0.38

# %%
df = pd.read_csv('C:\\Users\\KRISHNA\\Desktop\\Programming\\Data Science\\Test CSV files\\rows10.csv')
df.dropna(axis = 1, thresh = 7)
# Out:
#    S.NO                                              Name                 Frc  \
# 0   1.0  Eldon Base for stackable storage shelf, platinum  Muhammed MacIntyre
# 1   2.0                                               NaN        Barry French
# 2   3.0  Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl        Barry French
# 3   4.0                                              R380                 NaN
# 4   5.0                                                no                 yes
# 5   6.0                                               NaN      Carlos Soltero
# 6   NaN                                               NaN                 NaN
# 7   8.0           SAFCO Mobile Desk Side File, Wire Frame                 NaN
# 8   9.0             SAFCO Commercial Wire Shelving, Black      Monica Federle
# 9  10.0                                         Xerox 198     Dorothy Badders
#
#      val    deval     anl  grscc location                            part
# 0    3.0  -213.25   38.94  35.00  Nunavut          Storage & Organization
# 1  293.0      NaN  208.16  68.02       no                      Appliances
# 2  293.0      yes    8.69   2.99  Nunavut  Binders and Binder Accessories
# 3  483.0  1198.97  195.99   3.99  Nunavut                             NaN
# 4  515.0    30.94   21.78   5.94  Nunavut                      Appliances
# 5  515.0      NaN    6.64   4.95  Nunavut              Office Furnishings
# 6    NaN      NaN     NaN    NaN      NaN                             NaN
# 7  613.0    127.7   42.76   6.22  Nunavut          Storage & Organization
# 8  643.0      yes  138.14  35.00  Nunavut          Storage & Organization
# 9  678.0  -226.36    4.98   8.33  Nunavut                           Paper

# %%
df = pd.read_csv('C:\\Users\\KRISHNA\\Desktop\\Programming\\Data Science\\Test CSV files\\rows10.csv')
df.dropna(subset = ['Frc'])
# Out:
#    S.NO                                              Name                 Frc  \
# 0   1.0  Eldon Base for stackable storage shelf, platinum  Muhammed MacIntyre
# 1   2.0                                               NaN        Barry French
# 2   3.0  Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl        Barry French
# 4   5.0                                                no                 yes
# 5   6.0                                               NaN      Carlos Soltero
# 8   9.0             SAFCO Commercial Wire Shelving, Black      Monica Federle
# 9  10.0                                         Xerox 198     Dorothy Badders
#
#    invert    val    deval     anl  grscc location  \
# 0     NaN    3.0  -213.25   38.94  35.00  Nunavut
# 1     NaN  293.0      NaN  208.16  68.02       no
# 2     NaN  293.0      yes    8.69   2.99  Nunavut
# 4     NaN  515.0    30.94   21.78   5.94  Nunavut
# 5     NaN  515.0      NaN    6.64   4.95  Nunavut
# 8     NaN  643.0      yes  138.14  35.00  Nunavut
# 9     NaN  678.0  -226.36    4.98   8.33  Nunavut
#
#                              part  mean
# 0          Storage & Organization  0.80
# 1                      Appliances   NaN
# 2  Binders and Binder Accessories  0.39
# 4                      Appliances  0.50
# 5              Office Furnishings  0.37
# 8          Storage & Organization   NaN
# 9                           Paper  0.38

# %%
df = pd.read_csv('C:\\Users\\KRISHNA\\Desktop\\Programming\\Data Science\\Test CSV files\\rows10.csv')
df.dropna(inplace = False)
df
# Out:
#    S.NO                                              Name                 Frc  \
# 0   1.0  Eldon Base for stackable storage shelf, platinum  Muhammed MacIntyre
# 1   2.0                                               NaN        Barry French
# 2   3.0  Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl        Barry French
# 3   4.0                                              R380                 NaN
# 4   5.0                                                no                 yes
# 5   6.0                                               NaN      Carlos Soltero
# 6   NaN                                               NaN                 NaN
# 7   8.0           SAFCO Mobile Desk Side File, Wire Frame                 NaN
# 8   9.0             SAFCO Commercial Wire Shelving, Black      Monica Federle
# 9  10.0                                         Xerox 198     Dorothy Badders
#
#    invert    val    deval     anl  grscc location  \
# 0     NaN    3.0  -213.25   38.94  35.00  Nunavut
# 1     NaN  293.0      NaN  208.16  68.02       no
# 2     NaN  293.0      yes    8.69   2.99  Nunavut
# 3     NaN  483.0  1198.97  195.99   3.99  Nunavut
# 4     NaN  515.0    30.94   21.78   5.94  Nunavut
# 5     NaN  515.0      NaN    6.64   4.95  Nunavut
# 6     NaN    NaN      NaN     NaN    NaN      NaN
# 7     NaN  613.0    127.7   42.76   6.22  Nunavut
# 8     NaN  643.0      yes  138.14  35.00  Nunavut
# 9     NaN  678.0  -226.36    4.98   8.33  Nunavut
#
#                              part  mean
# 0          Storage & Organization  0.80
# 1                      Appliances   NaN
# 2  Binders and Binder Accessories  0.39
# 3                             NaN  0.58
# 4                      Appliances  0.50
# 5              Office Furnishings  0.37
# 6                             NaN   NaN
# 7          Storage & Organization   NaN
# 8          Storage & Organization   NaN
# 9                           Paper  0.38

# %%
df = pd.read_csv('C:\\Users\\KRISHNA\\Desktop\\Programming\\Data Science\\Test CSV files\\rows10.csv')
df.dropna(inplace = True)
df
# Out:
#    S.NO                                               Name  \
# 0     1   Eldon Base for stackable storage shelf, platinum
# 2     3   Cardinal Slant-D® Ring Binder, Heavy Gauge Vinyl
# 4     5                                                 no
# 5     6  G.E. Longer-Life Indoor Recessed Floodlight Bulbs
# 6     7  Angle-D Binders with Locking Rings, Label Holders
# 9    10                                          Xerox 198
#
#                   Frc invert  val    deval    anl  grscc location  \
# 0  Muhammed MacIntyre    yes    3  -213.25  38.94  35.00  Nunavut
# 2        Barry French    yes  293      yes   8.69   2.99  Nunavut
# 4                 yes     no  515    30.94  21.78   5.94  Nunavut
# 5      Carlos Soltero    yes  515      yes   6.64   4.95  Nunavut
# 6        Carl Jackson     no  613   -54.04   7.30   7.72       no
# 9     Dorothy Badders     no  678  -226.36   4.98   8.33  Nunavut
#
#                              part  mean
# 0          Storage & Organization  0.80
# 2  Binders and Binder Accessories  0.39
# 4                      Appliances  0.50
# 5              Office Furnishings  0.37
# 6  Binders and Binder Accessories  0.38
# 9                           Paper  0.38
