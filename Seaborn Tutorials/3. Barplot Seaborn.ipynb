# %%
import seaborn as sns

# %%
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
"""
x=None,
    y=None,
    hue=None,
    data=None,
    order=None,
    hue_order=None,
    estimator=<function mean at 0x00000055D51DE820>,
    ci=95,
    n_boot=1000,
    units=None,
    seed=None,
    orient=None,
    color=None,
    palette=None,
    saturation=0.75,
    errcolor='.26',
    errwidth=None,
    capsize=None,
    dodge=True,
    ax=None,
"""

# %%
sns.barplot(x = df.total_bill)
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
sns.barplot(x = df.day , y= df.total_bill)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x = df.day , y= df.total_bill , hue = df.sex)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x = 'day' , y= 'total_bill' , hue = 'sex' , data = df)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
o = ['Sun','Fri','Thur','Sat']
sns.barplot(x = 'day' , y= 'total_bill' , hue = 'sex' , data = df , order = o)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
o = ['Sun','Fri','Thur','Sat']
ho = ['Female','Male']
sns.barplot(x = 'day' , y= 'total_bill' , hue = 'sex' , data = df , order = o , hue_order = ho)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
o = ['Sun','Fri','Thur','Sat']
ho = ['Female','Male']

import numpy as np

sns.barplot(x = 'day' , y= 'total_bill' , hue = 'sex' , data = df , order = o , hue_order = ho , estimator = np.mean)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
o = ['Sun','Fri','Thur','Sat']
ho = ['Female','Male']

import numpy as np

sns.barplot(x = 'day' , y= 'total_bill' , hue = 'sex' , data = df , order = o , hue_order = ho , estimator = np.max)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x = 'day' , y= 'total_bill' , hue = 'sex' , data = df , order = o , hue_order = ho , estimator = np.max , ci = 50)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x = 'day' , y= 'total_bill' , hue = 'sex' , data = df , order = o , hue_order = ho , estimator = np.max , ci = 50 , n_boot = 10)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x = 'day' , y= 'total_bill' , hue = 'sex' , data = df , order = o , hue_order = ho , estimator = np.max ,palette = "hot")
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x = 'day' , y= 'total_bill' , hue = 'sex' , data = df , order = o , hue_order = ho , estimator = np.max ,palette = "hot" , saturation = 0.4)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x = 'day' , y= 'total_bill' , hue = 'sex' , data = df , order = o , hue_order = ho , estimator = np.max ,palette = "hot" , errcolor = '0.5')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x = 'day' , y= 'total_bill' , hue = 'sex' , data = df , order = o , hue_order = ho , estimator = np.max ,palette = "hot" , errcolor = '0.5' , errwidth = 12)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
 sns.barplot(x = 'day' , y= 'total_bill' , hue = 'sex' , data = df , order = o , hue_order = ho , estimator = np.max ,palette = "hot" , errcolor = '0.5' , capsize = 0.6)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
 sns.barplot(x = 'day' , y= 'total_bill' , hue = 'sex' , data = df , order = o , hue_order = ho , estimator = np.max ,palette = "hot" , errcolor = '0.5' , capsize = 0.6 , dodge = False)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.set()
kwargs = {'alpha':0.7 , 'linestyle':":", 'linewidth':2  ,'edgecolor':'k'} 
sns.barplot(x = 'day' , y= 'total_bill' , data = df, **kwargs)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
kwargs = {'alpha':0.7 , 'linestyle':":", 'linewidth':2  ,'edgecolor':'k'} 
ax = sns.barplot(x = 'day' , y= 'total_bill' , data = df , **kwargs)
ax.set(title =  'Barplot of Tips DF', xlabel = 'days', ylabel = 'total bill')
# Out:
# [Text(0.5, 1.0, 'Barplot of Tips DF'),
#  Text(0.5, 0, 'days'),
#  Text(0, 0.5, 'total bill')]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(16,9))
sns.barplot(x = 'day' , y= 'total_bill' , data = df , **kwargs)
plt.title('Bar Plot of Days and Total Bill', fontsize = 50)
plt.xlabel('Days' , fontsize = 35)
plt.ylabel('Total Bill', fontsize = 35)

plt.savefig('D:\\myplot')
plt.show()
