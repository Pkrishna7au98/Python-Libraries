# %%
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
tips_df = sns.load_dataset("tips")
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.displot(tips_df["size"])
plt.show()

# %% [markdown]
# In the above output the line curve is too given  : It is known as KDE : Kernel Density Estimate/or

# %%
sns.distplot(tips_df["tip"])
plt.show()
# Out:
# C:\Users\KRISHNA\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
"""
a=None,
    bins=None,  #as a catagory >> to give range
    hist=True,
    kde=True,
    rug=False,
    fit=None,
    hist_kws=None,
    kde_kws=None,
    rug_kws=None,
    fit_kws=None,
    color=None,
    vertical=False,
    norm_hist=False,
    axlabel=None,
    label=None,
    ax=None,
    x=None,
"""

# %%
sns.distplot(tips_df["tip"] , bins=100)
plt.show()
# Out:
# C:\Users\KRISHNA\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(tips_df["tip"] , bins=100, hist = False)
plt.show()
# Out:
# C:\Users\KRISHNA\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(tips_df["tip"] , bins=100, hist = True , kde = False)
plt.show()
# Out:
# C:\Users\KRISHNA\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(tips_df["tip"] , bins=100, hist = False, rug = True)
plt.show()
# Out:
# C:\Users\KRISHNA\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\KRISHNA\anaconda3\lib\site-packages\seaborn\distributions.py:2055: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(tips_df["tip"] , bins=100, hist = False , rug = True , fit = norm)
plt.show()
# Out:
# C:\Users\KRISHNA\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\KRISHNA\anaconda3\lib\site-packages\seaborn\distributions.py:2055: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %%
 sns.distplot(tips_df["tip"] , bins=100, hist = True , rug = True , fit = norm , color = "r")
plt.show()
# Out:
# C:\Users\KRISHNA\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\KRISHNA\anaconda3\lib\site-packages\seaborn\distributions.py:2055: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %%
 sns.distplot(tips_df["tip"] , bins=100, hist = True , rug = True , fit = norm , color = "r", norm_hist = True, axlabel = "Tips given")
plt.show()
# Out:
# C:\Users\KRISHNA\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\KRISHNA\anaconda3\lib\site-packages\seaborn\distributions.py:2055: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(tips_df["tip"] , bins=100, hist = True , rug = True , fit = norm , color = "r", norm_hist = True, axlabel = "Tips given", label = "Plot Info")
plt.legend()
plt.show()
# Out:
# C:\Users\KRISHNA\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\KRISHNA\anaconda3\lib\site-packages\seaborn\distributions.py:2055: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %%
sns.histplot(tips_df["tip"] , bins=50  , color = "r", label = "Plot Info", kde =True)
plt.legend()
plt.show()

# %%
sns.set()
sns.histplot(tips_df["tip"] , bins=50  , color = "r", label = "Plot Info", kde =True)
plt.legend()
plt.show()

# %%
tips_df.total_bill.sort_values()
# Out:
# 67      3.07
# 92      5.75
# 111     7.25
# 172     7.25
# 149     7.51
#        ...
# 182    45.35
# 156    48.17
# 59     48.27
# 212    48.33
# 170    50.81
# Name: total_bill, Length: 244, dtype: float64

# %%
bins = [1,5,10,15,20,25,30,35,40,45,50,55]
sns.set()
sns.distplot(tips_df["total_bill"] , bins=bins)
plt.xticks(bins)
plt.show()
# Out:
# C:\Users\KRISHNA\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.set()
sns.distplot(tips_df["total_bill"] , hist_kws = {'color':'#DC143C'})
# Out:
# C:\Users\KRISHNA\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.set()
sns.distplot(tips_df["total_bill"] , hist_kws = {'color':'#DC143C', 'edgecolor':'#aaff00','linewidth':5 , 'linestyle':"--"})
plt.show()
# Out:
# C:\Users\KRISHNA\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(16,9))
sns.set()
sns.distplot(tips_df["total_bill"] , hist_kws = {'color':'#DC143C', 'edgecolor':'#aaff00','linewidth':5 , 'linestyle':"--",'alpha':0.8})
plt.show()
# Out:
# C:\Users\KRISHNA\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(16,9))
sns.set()
sns.distplot(tips_df["total_bill"] , hist_kws = {'color':'#DC143C', 'edgecolor':'#aaff00','linewidth':5 , 'linestyle':"--",'alpha':0.8}, kde_kws = {'color':'#8e00ce','linewidth':7 , 'linestyle':"--",'alpha':0.8})
plt.show()
# Out:
# C:\Users\KRISHNA\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(16,9))
sns.set()
sns.distplot(tips_df["total_bill"] , hist_kws = {'color':'#DC143C', 'edgecolor':'#aaff00','linewidth':5 , 'linestyle':"--",'alpha':0.8},
             kde_kws = {'color':'#8e00ce','linewidth':7 , 'linestyle':"--",'alpha':0.8} ,
             rug=True )
plt.show()
# Out:
# C:\Users\KRISHNA\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\KRISHNA\anaconda3\lib\site-packages\seaborn\distributions.py:2055: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(16,9))
sns.set()
sns.distplot(tips_df["total_bill"] , hist_kws = {'color':'#DC143C', 'edgecolor':'#aaff00','linewidth':5 , 'linestyle':"--",'alpha':0.8},
             kde = True,
             kde_kws = {'color':'#8e00ce','linewidth':7 , 'linestyle':"--",'alpha':0.8} ,
             rug=True,
             rug_kws = {'color':'#8e00ce','linewidth':7 , 'linestyle':"--",'alpha':0.8})
plt.show()
# Out:
# C:\Users\KRISHNA\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\KRISHNA\anaconda3\lib\site-packages\seaborn\distributions.py:2055: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(16,9))
sns.set()
sns.distplot(tips_df["total_bill"] , hist_kws = {'color':'#DC143C', 'edgecolor':'#aaff00','linewidth':5 , 'linestyle':"--",'alpha':0.8},
             kde = False,
             fit = norm,
             fit_kws = {'color':'#8e00ce','linewidth':7 , 'linestyle':"--",'alpha':0.8} ,
             rug=True,
             rug_kws = {'color':'#8e00ce','linewidth':7 , 'linestyle':"--",'alpha':0.8})
plt.show()
# Out:
# C:\Users\KRISHNA\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\KRISHNA\anaconda3\lib\site-packages\seaborn\distributions.py:2055: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(16,9))
sns.set()
sns.distplot(tips_df["total_bill"] , hist_kws = {'color':'#DC143C', 'edgecolor':'#aaff00','linewidth':5 , 'linestyle':"--",'alpha':0.8},
             kde = False,
             fit = norm,
             fit_kws = {'color':'#8e00ce','linewidth':7 , 'linestyle':"--",'alpha':0.8} ,
             rug=True,
             rug_kws = {'color':'#8e00ce','linewidth':7 , 'linestyle':"--",'alpha':0.8},
             label = "TB")
plt.title("Histogram of Restaurant Bills")
plt.xlabel('Total Bill')
plt.show()
# Out:
# C:\Users\KRISHNA\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\KRISHNA\anaconda3\lib\site-packages\seaborn\distributions.py:2055: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## TO plot multiple histograms in one image

# %%
sns.distplot(tips_df["tip"] , bins=10)
sns.distplot(tips_df["total_bill"] , bins=10)
sns.distplot(tips_df["size"] , bins=10)
plt.show()
# Out:
# C:\Users\KRISHNA\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\KRISHNA\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...
